# %% [markdown]
# # Sets

# %%
#has no dublicate content
set_var = set()
type(set_var)
# Out:
# set

# %%
set_var ={1,2,3,4,3}

# %%
set_var
# Out:
# {1, 2, 3, 4}

# %%
set_var ={'IronMan','Avengers','Hitman'}
print(set_var)
type(set_var)
# Out:
# {'Avengers', 'IronMan', 'Hitman'}
# set

# %%
#indexing not find 
set_var.add('Hulk')
print(set_var)
# Out:
# {'Avengers', 'IronMan', 'Hulk', 'Hitman'}

# %%
set1 = {'IronMan','Avengers','Hitman'}
set2 = {'IronMan','Avengers','Hitman','Hulk'}

# %%
set2.intersection(set1)
# Out:
# {'Avengers', 'Hitman', 'IronMan'}

# %%
set2.difference(set1)
# Out:
# {'Hulk'}

# %%
set2.difference_update(set1)
print(set2)
# Out:
# {'Hulk'}

# %% [markdown]
# # Dictionaries

# %%
my_dict = { 'car1':'Audi' ,'car2':'BMW','car3':'Mercidies'}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict['car1']
# Out:
# 'Audi'

# %%
for x in my_dict:
    print(x)
# Out:
# car1
# car2
# car3

# %%
for x in my_dict.values():
    print(x)
# Out:
# Audi
# BMW
# Mercidies

# %%
for x in my_dict.items():
    print(x)
# Out:
# ('car1', 'Audi')
# ('car2', 'BMW')
# ('car3', 'Mercidies')

# %%
my_dict ['car4'] = 'Audi 20'
my_dict
# Out:
# {'car1': 'Audi', 'car2': 'BMW', 'car3': 'Mercidies', 'car4': 'Audi 20'}

# %% [markdown]
# ## Nested Dictionary

# %%
car1_model = {'mercidies':1960}
car2_model = {'audi':1970}
car3_model = {'ambassadors':1980}

car_type ={ 'car1':car1_model,'car2':car2_model,'car3':car3_model}

# %%
print(car_type)
# Out:
# {'car1': {'mercidies': 1960}, 'car2': {'audi': 1970}, 'car3': {'ambassadors': 1980}}

# %% [markdown]
# # Tuples

# %%
my_tuple = ('krish','naik','jhon')

# %%
#not replaxeable
type(my_tuple)
# Out:
# tuple
