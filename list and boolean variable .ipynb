# %%
my_str = "Krish Naik"

# %%
print(my_str .isalnum()) #if all carecter are number
print(my_str .isalpha()) #all charecter string arev alphabetic
print(my_str .isdigit()) #string contrains digit
print(my_str .istitle()) #string contrains title words
print(my_str .isupper()) 
print(my_str .islower())
print(my_str .isspace())
print(my_str .endswith('k'))
print(my_str .startswith('K'))
# Out:
# False
# False
# False
# True
# False
# False
# False
# True
# True

# %%
str_example ='Hello World'
my_str1 ='krish'

# %%
my_str1.isalpha() or str_example.isnum()
# Out:
# True

# %%
lst_examble = ['math','che',100,200,300]

# %%
type(lst_examble)
# Out:
# list

# %%
len(lst_examble)
# Out:
# 5

# %%
lst_examble.append('english')
print(lst_examble)
# Out:
# ['math', 'che', 100, 200, 300, 'english']

# %%
#indexing it lst
lst_examble[4]
# Out:
# 300

# %%
print(lst_examble[1:])
# Out:
# ['che', 100, 200, 300, 'english']

# %%
print(lst_examble[1:5])
# Out:
# ['che', 100, 200, 300]

# %%
lst_examble.insert(2,'bangla')

# %%
print(lst_examble)
# Out:
# ['math', 'che', 'bangla', 100, 200, 300, 'english']

# %%
lst_examble
# Out:
# ['math', 'che', 'bangla', 100, 200, 300, 'english']

# %%
lst = [1,2,3,4,5,6]
lst.extend([8,9])

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 8, 9]

# %%
sum(lst)
# Out:
# 38

# %%
lst.pop()
# Out:
# 9

# %%
lst
# Out:
# [1, 2, 3, 4, 5, 6, 8]

# %%
lst.pop(0)
# Out:
# 1

# %%
lst
# Out:
# [2, 3, 4, 5, 6, 8]

# %% [markdown]
# # count():Calculate total ocurrence of given element of list

# %%
lst.count(4)
# Out:
# 1

# %%
lst.count(0)
# Out:
# 0

# %%
lst.index(3,1,5)
# Out:
# 1

# %%
lst
# Out:
# [2, 3, 4, 5, 6, 8]

# %%
min(lst)
# Out:
# 2

# %%
max(lst)
# Out:
# 8

# %%
lst*2
# Out:
# [2, 3, 4, 5, 6, 8, 2, 3, 4, 5, 6, 8]
